# %% [markdown]
# <a href="https://colab.research.google.com/github/bhparmar/3150312/blob/main/ImageProcessing1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from skimage.io import imread
from skimage.color import rgb2lab, lab2rgb
import matplotlib.pylab as plt
from google.colab.patches import cv2_imshow
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def read_file(filename):
  image = cv2.imread(filename)
  cv2_imshow(image)
  return image

# %%
uploaded = files.upload()

filename = next(iter(uploaded))
image = read_file(filename)
# Out:
#      <input type="file" id="files-6405d4d3-6262-427a-89e6-64917d391dd0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6405d4d3-6262-427a-89e6-64917d391dd0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IMG-20200108-WA0040.jpg to IMG-20200108-WA0040.jpg
# <PIL.Image.Image image mode=RGB size=802x564 at 0x7FE0769B0890>

# %%
image1 = rgb2lab(image)

# %%
image1[...,1] = image1[...,2] = 0

# %%
image1 = lab2rgb(image1)

# %%
plt.figure(figsize=(20,10))
plt.subplot(122), plt.imshow(image1), plt.axis('off'), plt.title('Gray Scale Image', size=20)
plt.show()
